# %%
# Run in a Jupyter Notebook.
import tensorflow_model_analysis as tfma
from google.protobuf import text_format

eval_config = text_format.Parse("""
  ## Model information
  model_specs {
    # This assumes a serving model with a "serving_default" signature.
    label_key: "label"
    example_weight_key: "weight"
  }
  ## Post export metric information
  metrics_specs {
    # This adds AUC and as a post training metric. If the model has built in
    # training metrics which also contains AUC, this metric will replace it.
    metrics { class_name: "AUC" }
    # ... other post training metrics ...

    # Plots are also configured here...
    metrics { class_name: "ConfusionMatrixPlot" }
  }
  ## Slicing information
  slicing_specs {}  # overall slice
  slicing_specs {
    feature_keys: ["age"]
  }
""", tfma.EvalConfig())

eval_shared_model = tfma.default_eval_shared_model(
    eval_saved_model_path='D:\machine_learning_project\Bushido_IDS\bushido', eval_config=eval_config)

eval_result = tfma.run_model_analysis(
    eval_shared_model=eval_shared_model,
    eval_config=eval_config)
    # This assumes your data is a TFRecords file containing records in the
    # tf.train.Example format.
    #data_location='/path/to/file/containing/tfrecords',
    #output_path='/path/for/output')

tfma.view.render_slicing_metrics(eval_result)
# Out:
# WARNING:absl:Tensorflow version (2.4.1) found. Note that TFMA support for TF 2.0 is currently in beta
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-a496700e6fa5> in <module>
#      30     eval_saved_model_path='D:\machine_learning_project\Bushido_IDS\bushido', eval_config=eval_config)
#      31
# ---> 32 eval_result = tfma.run_model_analysis(
#      33     eval_shared_model=eval_shared_model,
#      34     eval_config=eval_config)
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\tensorflow_model_analysis\api\model_eval_lib.py in run_model_analysis(eval_shared_model, eval_config, data_location, file_format, output_path, extractors, evaluators, writers, pipeline_options, slice_spec, write_config, compute_confidence_intervals, min_slice_size, random_seed_for_testing, schema)
#    1237                 arrow_schema=tfxio.ArrowSchema(),
#    1238                 tensor_representations=tfxio.TensorRepresentations())
# -> 1239         data = p | 'ReadFromTFRecordToArrow' >> tfxio.BeamSource()
#    1240       else:
#    1241         data = p | 'ReadFromTFRecord' >> beam.io.ReadFromTFRecord(
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\transforms\ptransform.py in __ror__(self, pvalueish, _unused)
#    1059
#    1060   def __ror__(self, pvalueish, _unused=None):
# -> 1061     return self.transform.__ror__(pvalueish, self.label)
#    1062
#    1063   def expand(self, pvalue):
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\transforms\ptransform.py in __ror__(self, left, label)
#     574     pvalueish = _SetInputPValues().visit(pvalueish, replacements)
#     575     self.pipeline = p
# --> 576     result = p.apply(self, pvalueish, label)
#     577     if deferred:
#     578       return result
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     646       try:
#     647         old_label, transform.label = transform.label, label
# --> 648         return self.apply(transform, pvalueish)
#     649       finally:
#     650         transform.label = old_label
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     689         transform.type_check_inputs(pvalueish)
#     690
# --> 691       pvalueish_result = self.runner.apply(transform, pvalueish, self._options)
#     692
#     693       if type_options is not None and type_options.pipeline_type_check:
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\runners\runner.py in apply(self, transform, input, options)
#     186       m = getattr(self, 'apply_%s' % cls.__name__, None)
#     187       if m:
# --> 188         return m(transform, input, options)
#     189     raise NotImplementedError(
#     190         'Execution of [%s] not implemented in runner %s.' % (transform, self))
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\runners\runner.py in apply_PTransform(self, transform, input, options)
#     216   def apply_PTransform(self, transform, input, options):
#     217     # The base case of apply is to call the transform's expand.
# --> 218     return transform.expand(input)
#     219
#     220   def run_transform(self,
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\transforms\ptransform.py in expand(self, pcoll)
#     965       # Might not be a function.
#     966       pass
# --> 967     return self._fn(pcoll, *args, **kwargs)
#     968
#     969   def default_label(self):
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\tfx_bsl\tfxio\record_based_tfxio.py in _PTransformFn(pcoll_or_pipeline)
#     178       """Converts raw records to RecordBatches."""
#     179       return (
# --> 180           pcoll_or_pipeline
#     181           | "RawRecordBeamSource" >> self.RawRecordBeamSource()
#     182           | "RawRecordToRecordBatch" >> self.RawRecordToRecordBatch(batch_size))
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pvalue.py in __or__(self, ptransform)
#     140
#     141   def __or__(self, ptransform):
# --> 142     return self.pipeline.apply(ptransform, self)
#     143
#     144
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     635     """
#     636     if isinstance(transform, ptransform._NamedPTransform):
# --> 637       return self.apply(
#     638           transform.transform, pvalueish, label or transform.label)
#     639
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     646       try:
#     647         old_label, transform.label = transform.label, label
# --> 648         return self.apply(transform, pvalueish)
#     649       finally:
#     650         transform.label = old_label
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     689         transform.type_check_inputs(pvalueish)
#     690
# --> 691       pvalueish_result = self.runner.apply(transform, pvalueish, self._options)
#     692
#     693       if type_options is not None and type_options.pipeline_type_check:
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\runners\runner.py in apply(self, transform, input, options)
#     186       m = getattr(self, 'apply_%s' % cls.__name__, None)
#     187       if m:
# --> 188         return m(transform, input, options)
#     189     raise NotImplementedError(
#     190         'Execution of [%s] not implemented in runner %s.' % (transform, self))
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\runners\runner.py in apply_PTransform(self, transform, input, options)
#     216   def apply_PTransform(self, transform, input, options):
#     217     # The base case of apply is to call the transform's expand.
# --> 218     return transform.expand(input)
#     219
#     220   def run_transform(self,
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\transforms\ptransform.py in expand(self, pcoll)
#     965       # Might not be a function.
#     966       pass
# --> 967     return self._fn(pcoll, *args, **kwargs)
#     968
#     969   def default_label(self):
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\tfx_bsl\tfxio\record_based_tfxio.py in _PTransformFn(pcoll_or_pipeline)
#     103     @beam.typehints.with_output_types(bytes)
#     104     def _PTransformFn(pcoll_or_pipeline: Any):
# --> 105       return (pcoll_or_pipeline
#     106               | "ReadRawRecords" >> self._RawRecordBeamSourceInternal()
#     107               | "CollectRawRecordTelemetry" >> telemetry.ProfileRawRecords(
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pvalue.py in __or__(self, ptransform)
#     140
#     141   def __or__(self, ptransform):
# --> 142     return self.pipeline.apply(ptransform, self)
#     143
#     144
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     635     """
#     636     if isinstance(transform, ptransform._NamedPTransform):
# --> 637       return self.apply(
#     638           transform.transform, pvalueish, label or transform.label)
#     639
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     646       try:
#     647         old_label, transform.label = transform.label, label
# --> 648         return self.apply(transform, pvalueish)
#     649       finally:
#     650         transform.label = old_label
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\pipeline.py in apply(self, transform, pvalueish, label)
#     689         transform.type_check_inputs(pvalueish)
#     690
# --> 691       pvalueish_result = self.runner.apply(transform, pvalueish, self._options)
#     692
#     693       if type_options is not None and type_options.pipeline_type_check:
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\runners\runner.py in apply(self, transform, input, options)
#     186       m = getattr(self, 'apply_%s' % cls.__name__, None)
#     187       if m:
# --> 188         return m(transform, input, options)
#     189     raise NotImplementedError(
#     190         'Execution of [%s] not implemented in runner %s.' % (transform, self))
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\runners\runner.py in apply_PTransform(self, transform, input, options)
#     216   def apply_PTransform(self, transform, input, options):
#     217     # The base case of apply is to call the transform's expand.
# --> 218     return transform.expand(input)
#     219
#     220   def run_transform(self,
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\transforms\ptransform.py in expand(self, pcoll)
#     965       # Might not be a function.
#     966       pass
# --> 967     return self._fn(pcoll, *args, **kwargs)
#     968
#     969   def default_label(self):
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\tfx_bsl\tfxio\record_based_tfxio.py in ReadTfRecord(pipeline, file_pattern)
#     336   for i, f in enumerate(file_pattern):
#     337     pcolls.append(pipeline
# --> 338                   | "ReadFromTFRecord[%d]" % i >> beam.io.ReadFromTFRecord(
#     339                       f, coder=beam.coders.BytesCoder()))
#     340
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\io\tfrecordio.py in __init__(self, file_pattern, coder, compression_type, validate)
#     257     """
#     258     super(ReadFromTFRecord, self).__init__()
# --> 259     self._source = _TFRecordSource(
#     260         file_pattern, coder, compression_type, validate)
#     261
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\io\tfrecordio.py in __init__(self, file_pattern, coder, compression_type, validate)
#     172   def __init__(self, file_pattern, coder, compression_type, validate):
#     173     """Initialize a TFRecordSource.  See ReadFromTFRecord for details."""
# --> 174     super(_TFRecordSource, self).__init__(
#     175         file_pattern=file_pattern,
#     176         compression_type=compression_type,
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\io\filebasedsource.py in __init__(self, file_pattern, min_bundle_size, compression_type, splittable, validate)
#     126     self._splittable = splittable
#     127     if validate and file_pattern.is_accessible():
# --> 128       self._validate()
#     129
#     130   def display_data(self):
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\options\value_provider.py in _f(self, *args, **kwargs)
#     194         if not obj.is_accessible():
#     195           raise error.RuntimeValueProviderError('%s not accessible' % obj)
# --> 196       return fnc(self, *args, **kwargs)
#     197
#     198     return _f
#
# c:\users\root\appdata\local\programs\python\python38\lib\site-packages\apache_beam\io\filebasedsource.py in _validate(self)
#     189     match_result = FileSystems.match([pattern], limits=[1])[0]
#     190     if len(match_result.metadata_list) <= 0:
# --> 191       raise IOError('No files found based on the file pattern %s' % pattern)
#     192
#     193   def split(
#
# OSError: No files found based on the file pattern
